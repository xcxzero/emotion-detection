# %%
import cv2
import matplotlib.pyplot as pt
from deepface import DeepFace
img=cv2.imread('fear.jpg')

# %%
pt.imshow(img)

# %%
predictions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  4.67it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.3747659754287034,
#   'disgust': 0.0007114931638563285,
#   'fear': 95.78604152369005,
#   'happy': 0.0017713025661867778,
#   'sad': 0.006178303729209232,
#   'surprise': 3.8302029573675447,
#   'neutral': 0.00031765578875294563},
#  'dominant_emotion': 'fear',
#  'region': {'x': 196, 'y': 92, 'w': 189, 'h': 189},
#  'age': 25,
#  'gender': 'Man',
#  'race': {'asian': 0.16831789398565888,
#   'indian': 0.6000054068863392,
#   'black': 0.04874549631495029,
#   'white': 65.84497094154358,
#   'middle eastern': 18.981820344924927,
#   'latino hispanic': 14.356139302253723},
#  'dominant_race': 'white'}
